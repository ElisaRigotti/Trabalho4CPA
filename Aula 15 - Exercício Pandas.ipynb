# %% [markdown]
# # Exercício de Fixação do pandas - Compras de Ecommerce
#
# **Elisa Rigotti**
#
# **Maria Júlia Escobar**
#
# **Michele Trindade**
#
# Neste exercício, você receberá alguns dados falsos sobre algumas compras feitas pela Amazon. Utilize instruções da biblioteca pandas para responder as perguntas e completar as tarefas. As respostas esperadas foram deixadas no notebook. A maioria das tarefas pode ser resolvida de diferentes maneiras.
#
# Observe também que todas essas questões podem ser respondidas com uma linha de código.
# ____

# %% [markdown]
# **Exercício 1**: Importe pandas e leia o arquivo `compras.csv` e configure-o para um DataFrame chamado ecom.

# %%
import pandas as pd

# %%
ecom = pd.read_csv('compras.csv')

# %% [markdown]
# **Exercício 2**: Mostre as 4 primeiras linhas do dataset

# %%
ecom.head(4)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# 2       Simpson, Williams and Pham      675957666125       08/19
# 3  Williams, Marshall and Buchanan  6011578504430710       02/24
#
# ...

# %% [markdown]
# **Exercício 3**: Quantas colunas e linhas existem nesse dataset?

# %%
ecom.shape
# Out:
# (10000, 14)

# %% [markdown]
# **Exercício 4**: Classifique cada coluna desse dataframe de acordo com o tipo de dado (categórico ou numérico)

# %%
print(ecom.dtypes)
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %% [markdown]
# **Exercício 5**: Qual o valor médio de compras?

# %%
ecom['Purchase Price'].mean()
# Out:
# np.float64(50.347302)

# %% [markdown]
# **Exercício 6**: Qual foi o maior e o menor preço de compras desse dataset?

# %%
# maior
ecom['Purchase Price'].max()
# Out:
# 99.99

# %%
# menor
ecom['Purchase Price'].min()
# Out:
# 0.0

# %% [markdown]
# **Exercício 7**: Quantas compras foram feitas no horário AM e quantas foram feitas no horário PM?

# %%
ecom['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %% [markdown]
# **Exercício 8**: Quantos clientes tem o inglês (en) como idioma de uso do site?

# %%
(ecom['Language'] == 'en').sum()
# Out:
# np.int64(1098)

# %% [markdown]
# **Exercício 9**: Quais as cinco profissões mais comuns?

# %%
ecom['Job'].value_counts().head()
# Out:
# Job
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
# Name: count, dtype: int64

# %% [markdown]
# **Exercício 10**: Qual o preço da compra que veio do lote `90 WT`?

# %%
ecom[ecom['Lot'] == '90 WT']['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %% [markdown]
# **Exercício 11**: Qual é o email da pessoa que possui o seguinte número do cartão de crédito: `4926535242672853`?

# %%
ecom[ecom['Credit Card'] == 4926535242672853]['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %% [markdown]
# **Exercício 12**: Qual o endereço, e-mail e profissão das pessoas têm o American Express como seu fornecedor de cartão de crédito **e** fizeram uma compra acima de US$95?

# %%
ecom[(ecom['CC Provider'] == 'American Express') & (ecom['Purchase Price'] > 95)][['Address', 'Email', 'Job']]
# Out:
#                                                 Address  \
# 9       3795 Dawson Extensions\nLake Tinafort, ID 88739
# 280   81060 Dustin Causeway Apt. 503\nPort Danielche...
# 372              359 Stanley Coves\nSalasfort, SD 59457
# 677       4855 Peter Bridge\nJohnsonberg, PA 90599-0009
# 766             386 Alisha Unions\nSteelebury, ND 19782
# 1225    916 Amanda Heights\nNew Johnland, CA 52112-8572
# 1381  79284 Lisa Mews Suite 069\nKellyborough, CT 71...
# 1385  67796 James Keys Suite 656\nSouth Katieshire, ...
# 1568       76108 Barker Manors\nEast Amy, PW 49544-5921
# 1727  478 Anita Hill Apt. 766\nAverymouth, FM 50629-...
# 2146           557 Barton Harbor\nFuentesport, VI 29961
# 2264   040 Ingram Way Suite 602\nEast Matthew, AR 67341
# 2267  216 Olivia Court Apt. 439\nTonyshire, IN 19159...
# 2642  899 Williams Prairie Suite 234\nEast Hunterbur...
# 2828  20135 Miller Green Apt. 763\nGarciaville, KY 6...
# 3291             58939 Reese Cove\nSouth Ross, MA 54531
# ...

# %% [markdown]
# **Exercício 13**: Crie duas novas colunas no dataframe contendo o mês e o ano de expiração do cartão de crédito.
#
# *Esse exercício vai precisar de mais do que uma linha de código*

# %%
ecom['Mês Exp'] = ecom['CC Exp Date'].str.split('/').str[0] # Quebramos a string 'MM/YY' em uma lista ['MM', 'YY'] e pegamos o primeiro item ([0])
ecom['Ano Exp'] = ecom['CC Exp Date'].str.split('/').str[1] # Segundo item da lista ([1])
print(ecom[['CC Exp Date', 'Mês Exp', 'Ano Exp']].head())
# Out:
#   CC Exp Date Mês Exp Ano Exp
# 0       02/20      02      20
# 1       11/18      11      18
# 2       08/19      08      19
# 3       02/24      02      24
# 4       10/25      10      25

# %% [markdown]
# **Exercício 14**: Obtenha um resumo estatístico, com a medida dos cinco números, para o valor da compra

# %%
ecom['Purchase Price'].describe()
# Out:
# count    10000.000000
# mean        50.347302
# std         29.015836
# min          0.000000
# 25%         25.150000
# 50%         50.505000
# 75%         75.770000
# max         99.990000
# Name: Purchase Price, dtype: float64

# %% [markdown]
# **Exercício 15**: Obtenha um resumo para a variável Idioma

# %%
ecom['Language'].describe()
# Out:
# count     10000
# unique        9
# top          de
# freq       1155
# Name: Language, dtype: object

# %% [markdown]
# **Exercício 16**: Obtenha uma lista de profissões únicas nesse dataset.

# %%
ecom['Job'].unique()
# Out:
# array(['Scientist, product/process development', 'Drilling engineer',
#        'Customer service manager', 'Fine artist', 'Fish farm manager',
#        'Dancer', 'Event organiser', 'Financial manager',
#        'Forensic scientist', 'Development worker, community',
#        'Diagnostic radiographer', 'Surveyor, quantity',
#        'Accountant, chartered public finance', 'Acupuncturist',
#        'Retail manager', 'Therapist, art', 'Designer, jewellery',
#        'Photographer', 'Designer, interior/spatial',
#        'Public relations officer', 'Presenter, broadcasting',
#        'Field seismologist', 'Musician',
#        'Training and development officer', "Barrister's clerk",
#        'Careers adviser', 'Scientist, research (life sciences)',
#        'Recycling officer', 'Fisheries officer', 'Sales executive',
#        'Civil Service fast streamer', 'Theatre stage manager',
#        'Therapist, music', 'Lecturer, further education',
# ...

# %% [markdown]
# **Exercício 17**: Mostre o número de compras feitas por cada categoria profissional no e-commerce.

# %%
ecom['Job'].value_counts()
# Out:
# Job
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
#                                  ..
# Prison officer                    7
# Editor, film/video                6
# Actuary                           6
# Information systems manager       5
# Investment analyst                5
# Name: count, Length: 623, dtype: int64

# %% [markdown]
# **Exercício 18**: Mostre o maior valor gasto por cada categoria profissional no e-commerce.

# %%
ecom.groupby('Job')['Purchase Price'].max()
# Out:
# Job
# Academic librarian                  95.15
# Accommodation manager               80.78
# Accountant, chartered               98.54
# Accountant, chartered certified     96.78
# Accountant, chartered management    99.90
#                                     ...
# Water quality scientist             95.60
# Web designer                        95.84
# Wellsite geologist                  98.42
# Writer                              92.33
# Youth worker                        98.62
# Name: Purchase Price, Length: 623, dtype: float64

# %% [markdown]
# **Exercício 19**: Agrupe os dados por idioma e mostre o número de compras, a média e o desvio padrão para cada agrupamento.

# %%
ecom.groupby('Language')['Purchase Price'].agg(['count', 'mean', 'std'])
# Out:
#           count       mean        std
# Language
# de         1155  50.254485  29.043419
# el         1137  51.555356  28.685787
# en         1098  51.103015  28.504003
# es         1095  49.366977  29.189423
# fr         1097  49.476718  29.475620
# it         1086  50.001004  29.331665
# pt         1118  51.215546  28.552595
# ru         1155  49.927134  28.994335
# zh         1059  50.180198  29.406322

# %% [markdown]
# **Exercício 20**: Agrupe os dados por categoria funcional e idioma. Mostre o número de compras para cada um desses agrupamentos

# %%
ecom.groupby(['Job', 'Language']).size()
# Out:
# Job                 Language
# Academic librarian  de          1
#                     el          3
#                     en          2
#                     es          2
#                     fr          1
#                                ..
# Youth worker        en          1
#                     es          3
#                     fr          5
#                     it          1
#                     pt          1
# Length: 4647, dtype: int64

# %% [markdown]
# **Exercício 21**: Mostre o dataframe ordenado por idioma e empresa.

# %%
ecom.sort_values(by=['Language', 'Company'])
# Out:
#                                                 Address    Lot AM or PM  \
# 4727              PSC 2426, Box 0661\nAPO AP 07395-0585  39 AK       PM
# 6866        60922 Robert Villages\nNew George, MP 82575  94 cz       PM
# 8933              3848 Janet Plaza\nJasonstad, CA 99690  07 yM       AM
# 3219  484 Brandon Park Apt. 164\nPort Jeremyton, SC ...  47 zi       PM
# 5392             4066 Matthew Dam\nLindaville, ME 70257  87 YL       PM
# ...                                                 ...    ...      ...
# 6209                     USNS Turner\nFPO AE 37707-2767  91 gc       AM
# 538           249 Scott Loop\nSouth John, SC 82732-9487  77 mh       PM
# 8496  7185 Rivera Tunnel Apt. 837\nMeganberg, ME 450...  79 uX       PM
# 199   06825 Shannon Glen Suite 582\nLake Evelyn, GU ...  71 ZP       AM
# 4972  52271 Zachary Tunnel Suite 025\nFarleyside, NV...  74 tK       PM
#
#                                            Browser Info  \
# ...
